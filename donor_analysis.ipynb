# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# NayePankh Foundation — Exploratory Donor Data Analysis\n",
    "This interactive notebook handles data loading, profiling, and iterative sandbox plotting before automating the production code."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Load data from the repository pipeline\n",
    "df = pd.read_csv('../data/donor_dataset.csv')\n",
    "df.info()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Age Distribution Profile of Active Supporters"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(6, 4))\n",
    "sns.histplot(df['Age'], bins=5, kde=True, color='teal')\n",
    "plt.title('NayePankh Donor Base Age Demographics')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 13
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# NayePankh Foundation — Exploratory Donor Data Analysis\n",
#       8     "This interactive notebook handles data loading, profiling, and iterative sandbox plotting before automating the production code."
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
# ---> 13    "execution_count": null,
#      14    "metadata": {},
#      15    "outputs": [],
#      16    "source": [
#      17     "import pandas as pd\n",
#      18     "import matplotlib.pyplot as plt\n",
#      19     "import seaborn as sns\n",
#      20     "\n",
#      21     "# Load data from the repository pipeline\n",
# ...
